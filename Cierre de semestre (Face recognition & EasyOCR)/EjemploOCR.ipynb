# %%
import easyocr

# %%
reader = easyocr.Reader(['ja','en'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("japanese.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=555x418 at 0x22F6231B0B8>

# %%
reader.readtext('japanese.jpg', detail = 0)
# Out:
# ['ポ<捨て禁止!', 'NOLITTER', '清潔できれいな港区を', '港 区 MINATO CITY']

# %%
reader = easyocr.Reader(['fr'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("french.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=692x1024 at 0x21FDDB99160>

# %%
result = reader.readtext('french.jpg')
result
# Out:
# [([[215, 220], [372, 220], [372, 269], [215, 269]],
#   'Mairie du l"',
#   0.628117561340332),
#  ([[256, 321], [477, 321], [477, 383], [256, 383]],
#   'Palais du LOUVRE',
#   0.6028931736946106),
#  ([[242, 418], [515, 418], [515, 474], [242, 474]],
#   'LES ARTS DÉCORATIFS',
#   0.459642618894577),
#  ([[260, 538], [481, 538], [481, 590], [260, 590]],
#   'Musée du LOUVRE',
#   0.48540496826171875),
#  ([[197, 637], [281, 637], [281, 675], [197, 675]],
#   'Théâtre',
#   0.9916056990623474),
#  ([[195, 668], [378, 668], [378, 713], [195, 713]],
#   'du PALAIS- ROVAL',
#   0.7393258810043335)]

# %%
reader.readtext('french.jpg', detail = 0)
# Out:
# ['Mairie du l"',
#  'Palais du LOUVRE',
#  'LES ARTS DÉCORATIFS',
#  'Musée du LOUVRE',
#  'Théâtre',
#  'du PALAIS- ROVAL']

# %%
reader = easyocr.Reader(['en','es'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("spanish.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x21FCF4E5668>

# %%
result1 = reader.readtext('spanish.jpg')

# %%
result1
# Out:
# [([[462.18789204271775, 110.20793578368642],
#    [604.7779353663989, 95.75034211154359],
#    [607.8121079572823, 168.79206421631358],
#    [465.2220646336012, 183.24965788845643]],
#   'FIRE',
#   0.9838064908981323),
#  ([[315.51260315235277, 193.8663840980586],
#    [743.6366568949669, 145.46856608250968],
#    [748.4873968476472, 221.1336159019414],
#    [320.3633431050331, 269.5314339174903]],
#   'EXTINGUISHER',
#   0.7698209881782532),
#  ([[632, 616], [718, 616], [718, 692], [632, 692]], 'DE', 0.9967679977416992),
#  ([[338.8082821045064, 666.0357359985621],
#    [629.3584393986346, 626.6628618818885],
#    [635.1917178954936, 700.9642640014379],
#    [344.6415606013654, 740.3371381181115]],
#   'EXTINTOR',
#   0.982334554195404),
#  ([[365.51260315235277, 728.8663840980586],
#    [687.402295944883, 681.7748763039843],
#    [694.4873968476472, 756.1336159019414],
#    [373.59770405511694, 802.2251236960157]],
#   'INCENDIOS',
#   0.7153455018997192)]

# %%
reader.readtext('spanish.jpg', detail = 0)
# Out:
# ['FIRE', 'EXTINGUISHER', 'DE', 'EXTINTOR', 'INCENDIOS']

# %%
reader = easyocr.Reader(['es'])
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
import PIL
from PIL import ImageDraw
im = PIL.Image.open("spanish1.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1200 at 0x21F89F6CF28>

# %%
result2 = reader.readtext('spanish1.jpg')

# %%
result2
# Out:
# [([[218, 201], [991, 201], [991, 313], [218, 313]],
#   'PROHIBIDO',
#   0.8560012578964233),
#  ([[540, 572], [702, 572], [702, 744], [540, 744]],
#   '^o',
#   0.030663903802633286),
#  ([[507, 861], [979, 861], [979, 999], [507, 999]],
#   'PASO',
#   0.9804856777191162),
#  ([[237, 870], [453, 870], [453, 986], [237, 986]], 'EL', 0.9706934690475464)]

# %%
reader.readtext('spanish1.jpg', detail = 0)
# Out:
# ['PROHIBIDO', '^o', 'PASO', 'EL']
